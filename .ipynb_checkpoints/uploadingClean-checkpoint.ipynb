# %%
import pandas as pd
import numpy as np


# The first step is to load the data from the csv files into the IDE

#Importing from the accident excel file
ac=pd.read_csv("Accidents0515.csv", low_memory=False)

#Importing from the casuality excel file
cs=pd.read_csv("Casualties0515.csv",low_memory=False)

#Importing from the Vehicle excel file
vs=pd.read_csv("Vehicles0515.csv", low_memory=False)

# %%
#Dropping some cells that wont be used
ac1=ac.drop(['Location_Easting_OSGR','1st_Road_Class','Location_Northing_OSGR','Police_Force','1st_Road_Number','2nd_Road_Class','2nd_Road_Number','Pedestrian_Crossing-Human_Control','Pedestrian_Crossing-Physical_Facilities','Special_Conditions_at_Site','Carriageway_Hazards','LSOA_of_Accident_Location'],axis='columns',inplace=False)

# check if there exist nan values
print(ac1.isnull().values.any())

#filling in the missing values using forward fill
ac1.fillna(0)
print(ac1.isnull().values.any())

ac1.head()
# Out:
# True
# True
#   Accident_Index  Longitude   Latitude Accident_Severity Number_of_Vehicles  \
# 0  200501BS00001   -0.19117  51.489096                 2                  1
# 1  200501BS00002  -0.211708  51.520075                 3                  1
# 2  200501BS00003  -0.206458  51.525301                 3                  2
# 3  200501BS00004  -0.173862  51.482442                 3                  1
# 4  200501BS00005  -0.156618  51.495752                 3                  1
#
#   Number_of_Casualties      Date Day_of_Week   Time  \
# 0                    1  04-01-05           3  17:42
# 1                    1  05-01-05           4  17:36
# 2                    1  06-01-05           5   0:15
# 3                    1  07-01-05           6  10:35
# 4                    1  10-01-05           2  21:13
#
#   Local_Authority_(District) Local_Authority_(Highway) Road_Type Speed_limit  \
# 0                         12                 E09000020         6          30
# 1                         12                 E09000020         3          30
# 2                         12                 E09000020         6          30
# 3                         12                 E09000020         6          30
# 4                         12                 E09000020         6          30
#
#   Junction_Detail Junction_Control Light_Conditions Weather_Conditions  \
# 0               0               -1                1                  2
# 1               6                2                4                  1
# 2               0               -1                4                  1
# 3               0               -1                1                  1
# 4               0               -1                7                  1
#
#   Road_Surface_Conditions Urban_or_Rural_Area  \
# 0                       2                   1
# 1                       1                   1
# 2                       1                   1
# 3                       1                   1
# 4                       2                   1
#
#   Did_Police_Officer_Attend_Scene_of_Accident
# 0                                           1
# 1                                           1
# 2                                           1
# 3                                           1
# 4                                           1

# %%
#Dropping some cells that wont be used
cs1=cs.drop(['Pedestrian_Movement','Vehicle_Reference','Casualty_Reference','Sex_of_Casualty','Age_of_Casualty','Car_Passenger','Bus_or_Coach_Passenger','Pedestrian_Road_Maintenance_Worker','Casualty_Type','Casualty_Home_Area_Type'],axis='columns',inplace=False)
# check if there exist nan values
print(cs1.isnull().values.any())
#there are no nan values
#do other types of cleaing

cs1.head()
# Out:
# True

# %%
#Dropping some cells that wont be used
vs1=vs.drop(['Vehicle_Reference','Towing_and_Articulation','Junction_Location','Vehicle_Leaving_Carriageway','Hit_Object_off_Carriageway','Was_Vehicle_Left_Hand_Drive?','Journey_Purpose_of_Driver','Age_Band_of_Driver','Engine_Capacity_(CC)','Propulsion_Code','Driver_IMD_Decile','Driver_Home_Area_Type'],axis='columns',inplace=False)
# check if there exist nan values
print(vs1.isnull().values.any())

vs1.head()
# Out:
# True

# %%
#dropping the Accident_Index in cs dataframe
cs2=cs1.drop(['Accident_Index'],axis='columns',inplace=False)

#concatenate the dataframe now to join ac and cs (which lacks the accident_index because they would clash with that of ac)
all_data=pd.concat([ac1,cs2],axis='columns')

#dropping the Accident_Index in vs dataframe
vs2=vs1.drop(['Accident_Index'],axis='columns',inplace=False)

#concatenate the dataframe now to join all_data and vs (which lacks the accident_index because they would clash with that of all_data)
all_data_1=pd.concat([all_data,vs2],axis='columns')

all_data.head()
# Out:
#   Accident_Index  Longitude   Latitude Accident_Severity Number_of_Vehicles  \
# 0  200501BS00001   -0.19117  51.489096                 2                  1
# 1  200501BS00002  -0.211708  51.520075                 3                  1
# 2  200501BS00003  -0.206458  51.525301                 3                  2
# 3  200501BS00004  -0.173862  51.482442                 3                  1
# 4  200501BS00005  -0.156618  51.495752                 3                  1
#
#   Number_of_Casualties      Date Day_of_Week   Time  \
# 0                    1  04-01-05           3  17:42
# 1                    1  05-01-05           4  17:36
# 2                    1  06-01-05           5   0:15
# 3                    1  07-01-05           6  10:35
# 4                    1  10-01-05           2  21:13
#
#   Local_Authority_(District)  ... Junction_Control Light_Conditions  \
# 0                         12  ...               -1                1
# 1                         12  ...                2                4
# 2                         12  ...               -1                4
# 3                         12  ...               -1                1
# 4                         12  ...               -1                7
#
#   Weather_Conditions Road_Surface_Conditions Urban_or_Rural_Area  \
# 0                  2                       2                   1
# 1                  1                       1                   1
# 2                  1                       1                   1
# 3                  1                       1                   1
# 4                  1                       2                   1
#
#   Did_Police_Officer_Attend_Scene_of_Accident Casualty_Class  \
# 0                                           1              3
# 1                                           1              2
# 2                                           1              1
# 3                                           1              3
# 4                                           1              1
#
#   Age_Band_of_Casualty Casualty_Severity Pedestrian_Location
# 0                    7                 2                   1
# 1                    7                 3                   0
# 2                    9                 3                   0
# 3                    6                 3                   5
# 4                    8                 3                   0
#
# [5 rows x 24 columns]

# %%
import gmplot
#import gmaps

gmap2 = gmplot.GoogleMapPlotter.from_geocode( "Kampala") 
gmap2.apikey = "AIzaSyBHTpkmjqbfaCfh3uUqQOYINBki_Gw0gsU"
gmap2.draw("kampala.html")

gmap1 = gmplot.GoogleMapPlotter(53.043649, -0.915276, 13)
gmap1.apikey = "AIzaSyBHTpkmjqbfaCfh3uUqQOYINBki_Gw0gsU"

latitudes = all_data['Latitude'].values
longitudes = all_data['Longitude'].values

locations = [(latitudes, longitudes)]
gmap1.draw("map.html")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-69-36c94c005fb8> in <module>
#       2 #import gmaps
#       3
# ----> 4 gmap2 = gmplot.GoogleMapPlotter.from_geocode( "Kampala")
#       5 gmap2.apikey = "AIzaSyBHTpkmjqbfaCfh3uUqQOYINBki_Gw0gsU"
#       6 gmap2.draw("kampala.html")
#
# E:\Anaconda3\lib\site-packages\gmplot\gmplot.py in from_geocode(cls, location_string, zoom)
#      33     @classmethod
#      34     def from_geocode(cls, location_string, zoom=13):
# ---> 35         lat, lng = cls.geocode(location_string)
#      36         return cls(lat, lng, zoom)
#      37
#
# E:\Anaconda3\lib\site-packages\gmplot\gmplot.py in geocode(self, location_string)
#      41             'http://maps.googleapis.com/maps/api/geocode/json?address="%s"' % location_string)
#      42         geocode = json.loads(geocode.text)
# ---> 43         latlng_dict = geocode['results'][0]['geometry']['location']
#      44         return latlng_dict['lat'], latlng_dict['lng']
#      45
#
# IndexError: list index out of range

# %%
import gmaps
gmaps.configure(api_key="AIzaSyBHTpkmjqbfaCfh3uUqQOYINBki_Gw0gsU")
gmaps.figure()

area_cordinates=(53.043649, -0.915276)
gmaps.figure(center=area_cordinates, zoom_level=12)
# Out:
# <module 'gmaps' from 'E:\\Anaconda3\\lib\\site-packages\\gmaps\\__init__.py'>
