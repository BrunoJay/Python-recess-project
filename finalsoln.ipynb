# %%
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import TimeSeriesSplit
plt.style.use('ggplot')
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# # loading the accident dataset

# %%
accidents = pd.read_csv("Accident0515.csv",index_col="Accident_Index")
accidents.head()
# Out:
#                 Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# Accident_Index
# 200501BS00001                525680.0                178240.0  -0.191170
# 200501BS00002                524170.0                181650.0  -0.211708
# 200501BS00003                524520.0                182240.0  -0.206458
# 200501BS00004                526900.0                177530.0  -0.173862
# 200501BS00005                528060.0                179040.0  -0.156618
#
#                  Latitude  Police_Force  Accident_Severity  \
# Accident_Index
# 200501BS00001   51.489096             1                  2
# 200501BS00002   51.520075             1                  3
# 200501BS00003   51.525301             1                  3
# 200501BS00004   51.482442             1                  3
# 200501BS00005   51.495752             1                  3
#
#                 Number_of_Vehicles  Number_of_Casualties        Date  \
# Accident_Index
# ...

# %% [markdown]
# ###### checking for columns with missing values

# %%
accidents.columns[accidents.isnull().any()]
# Out:
# Index(['Location_Easting_OSGR', 'Location_Northing_OSGR', 'Longitude',
#        'Latitude', 'Time', 'LSOA_of_Accident_Location'],
#       dtype='object')

# %%
#deleting the least important columns
ac=accidents.drop(['Location_Easting_OSGR','Location_Northing_OSGR','Longitude','Latitude'
             ,'LSOA_of_Accident_Location'],axis='columns',inplace=False)
ac.head()
# Out:
#                 Police_Force  Accident_Severity  Number_of_Vehicles  \
# Accident_Index
# 200501BS00001              1                  2                   1
# 200501BS00002              1                  3                   1
# 200501BS00003              1                  3                   2
# 200501BS00004              1                  3                   1
# 200501BS00005              1                  3                   1
#
#                 Number_of_Casualties        Date  Day_of_Week   Time  \
# Accident_Index
# 200501BS00001                      1  04/01/2005            3  17:42
# 200501BS00002                      1  05/01/2005            4  17:36
# 200501BS00003                      1  06/01/2005            5  00:15
# 200501BS00004                      1  07/01/2005            6  10:35
# 200501BS00005                      1  10/01/2005            2  21:13
#
#                 Local_Authority_(District) Local_Authority_(Highway)  \
# Accident_Index
# ...

# %%
#check for more columns with missing values
ac.columns[ac.isnull().any()]
# Out:
# Index(['Time'], dtype='object')

# %%
#we check if the dataframe has columns with object datetypes...and if so we convert them to numeric datatypes....we do this coz 
#interpolation cnt work with obect datatypes in Timeseries
ac.dtypes
# Out:
# Police_Force                                    int64
# Accident_Severity                               int64
# Number_of_Vehicles                              int64
# Number_of_Casualties                            int64
# Date                                           object
# Day_of_Week                                     int64
# Time                                           object
# Local_Authority_(District)                      int64
# Local_Authority_(Highway)                      object
# 1st_Road_Class                                  int64
# 1st_Road_Number                                 int64
# Road_Type                                       int64
# Speed_limit                                     int64
# Junction_Detail                                 int64
# Junction_Control                                int64
# 2nd_Road_Class                                  int64
# 2nd_Road_Number                                 int64
# ...

# %%
#converting object datatypes to numeric datatypes
for col in ac:
    ac[col] = pd.to_numeric(ac[col], errors='coerce')#with errrors='coerce' any value tht cnt be converted to a number is
    #converted to NaN
ac.dtypes
# Out:
# Police_Force                                   int64
# Accident_Severity                              int64
# Number_of_Vehicles                             int64
# Number_of_Casualties                           int64
# Date                                           int64
# Day_of_Week                                    int64
# Time                                           int64
# Local_Authority_(District)                     int64
# Local_Authority_(Highway)                      int64
# 1st_Road_Class                                 int64
# 1st_Road_Number                                int64
# Road_Type                                      int64
# Speed_limit                                    int64
# Junction_Detail                                int64
# Junction_Control                               int64
# 2nd_Road_Class                                 int64
# 2nd_Road_Number                                int64
# Pedestrian_Crossing-Human_Control              int64
# ...

# %%
ac.interpolate(method='time')
# Out:
#                 Police_Force  Accident_Severity  Number_of_Vehicles  \
# Accident_Index
# 200501BS00001              1                  2                   1
# 200501BS00002              1                  3                   1
# 200501BS00003              1                  3                   2
# 200501BS00004              1                  3                   1
# 200501BS00005              1                  3                   1
# 200501BS00006              1                  3                   2
# 200501BS00007              1                  3                   2
# 200501BS00009              1                  3                   1
# 200501BS00010              1                  3                   2
# 200501BS00011              1                  3                   2
# 200501BS00012              1                  3                   1
# 200501BS00014              1                  3                   2
# 200501BS00015              1                  3                   1
# ...

# %%
print(ac.isnull().values.any())
# Out:
# False

# %% [markdown]
# # loading the casualities dataset

# %%
casualities= pd.read_csv("Casualities0515.csv",error_bad_lines = False,index_col="Accident_Index",warn_bad_lines = False)
casualities.head()
# Out:
#                 Vehicle_Reference  Casualty_Reference  Casualty_Class  \
# Accident_Index
# 200501BS00001                   1                   1               3
# 200501BS00002                   1                   1               2
# 200501BS00003                   2                   1               1
# 200501BS00004                   1                   1               3
# 200501BS00005                   1                   1               1
#
#                 Sex_of_Casualty  Age_of_Casualty  Age_Band_of_Casualty  \
# Accident_Index
# 200501BS00001                 1               37                     7
# 200501BS00002                 1               37                     7
# 200501BS00003                 1               62                     9
# 200501BS00004                 1               30                     6
# 200501BS00005                 1               49                     8
#
#                 Casualty_Severity  Pedestrian_Location  Pedestrian_Movement  \
# ...

# %% [markdown]
# ###### checking for columns with missing values

# %%
casualities.columns[casualities.isnull().any()]
# Out:
# Index([], dtype='object')

# %%
#check if there any object data types
casualities.dtypes
# Out:
# Vehicle_Reference                     int64
# Casualty_Reference                    int64
# Casualty_Class                        int64
# Sex_of_Casualty                       int64
# Age_of_Casualty                       int64
# Age_Band_of_Casualty                  int64
# Casualty_Severity                     int64
# Pedestrian_Location                   int64
# Pedestrian_Movement                   int64
# Car_Passenger                         int64
# Bus_or_Coach_Passenger                int64
# Pedestrian_Road_Maintenance_Worker    int64
# Casualty_Type                         int64
# Casualty_Home_Area_Type               int64
# dtype: object

# %%
casualities.interpolate(method='time')
# Out:
#                 Vehicle_Reference  Casualty_Reference  Casualty_Class  \
# Accident_Index
# 200501BS00001                   1                   1               3
# 200501BS00002                   1                   1               2
# 200501BS00003                   2                   1               1
# 200501BS00004                   1                   1               3
# 200501BS00005                   1                   1               1
# 200501BS00006                   2                   1               1
# 200501BS00007                   1                   1               1
# 200501BS00009                   1                   1               3
# 200501BS00009                   1                   2               3
# 200501BS00010                   1                   1               1
# 200501BS00010                   2                   2               1
# 200501BS00011                   1                   1               2
# ...

# %%
print(casualities.isnull().values.any())
# Out:
# False

# %% [markdown]
# # loading the vehicle dataset

# %%
vehicles= pd.read_csv("Vehicles0515.csv",error_bad_lines = False,index_col="Accident_Index",warn_bad_lines = False)
vehicles.head()
# Out:
#                Vehicle_Reference Vehicle_Type Towing_and_Articulation  \
# Accident_Index
# 200501BS00001                  1            9                       0
# 200501BS00002                  1           11                       0
# 200501BS00003                  1           11                       0
# 200501BS00003                  2            9                       0
# 200501BS00004                  1            9                       0
#
#                Vehicle_Manoeuvre Vehicle_Location-Restricted_Lane  \
# Accident_Index
# 200501BS00001                 18                                0
# 200501BS00002                  4                                0
# 200501BS00003                 17                                0
# 200501BS00003                  2                                0
# 200501BS00004                 18                                0
#
#                Junction_Location Skidding_and_Overturning  \
# Accident_Index
# ...

# %% [markdown]
# ###### checking for columns with misssing values

# %%
vehicles.columns[vehicles.isnull().any()]
# Out:
# Index(['Vehicle_Reference', 'Vehicle_Type', 'Towing_and_Articulation',
#        'Vehicle_Manoeuvre', 'Vehicle_Location-Restricted_Lane',
#        'Junction_Location', 'Skidding_and_Overturning',
#        'Hit_Object_in_Carriageway', 'Vehicle_Leaving_Carriageway',
#        'Hit_Object_off_Carriageway', '1st_Point_of_Impact',
#        'Was_Vehicle_Left_Hand_Drive?', 'Journey_Purpose_of_Driver',
#        'Sex_of_Driver', 'Age_of_Driver', 'Age_Band_of_Driver',
#        'Engine_Capacity_(CC)', 'Propulsion_Code', 'Age_of_Vehicle',
#        'Driver_IMD_Decile', 'Driver_Home_Area_Type'],
#       dtype='object')

# %%
#drop non important columns
vs=vehicles.drop(['Vehicle_Reference','Towing_and_Articulation','Junction_Location','Vehicle_Leaving_Carriageway',
                  'Hit_Object_off_Carriageway','Was_Vehicle_Left_Hand_Drive?','Age_Band_of_Driver','Engine_Capacity_(CC)',
                  'Propulsion_Code','Driver_IMD_Decile','Driver_Home_Area_Type'],axis='columns',inplace=False)
vs.head()
# Out:
#                Vehicle_Type Vehicle_Manoeuvre  \
# Accident_Index
# 200501BS00001             9                18
# 200501BS00002            11                 4
# 200501BS00003            11                17
# 200501BS00003             9                 2
# 200501BS00004             9                18
#
#                Vehicle_Location-Restricted_Lane Skidding_and_Overturning  \
# Accident_Index
# 200501BS00001                                 0                        0
# 200501BS00002                                 0                        0
# 200501BS00003                                 0                        0
# 200501BS00003                                 0                        0
# 200501BS00004                                 0                        0
#
#                Hit_Object_in_Carriageway 1st_Point_of_Impact  \
# Accident_Index
# 200501BS00001                          0                   1
# 200501BS00002                          0                   4
# ...

# %%
vs.columns[vs.isnull().any()]#vs.loc[:, vs.isnull().any()]in case you want the columns printed out
# Out:
# Index(['Vehicle_Type', 'Vehicle_Manoeuvre', 'Vehicle_Location-Restricted_Lane',
#        'Skidding_and_Overturning', 'Hit_Object_in_Carriageway',
#        '1st_Point_of_Impact', 'Journey_Purpose_of_Driver', 'Sex_of_Driver',
#        'Age_of_Driver', 'Age_of_Vehicle'],
#       dtype='object')

# %%
#handle the missing values
vs1= vs.fillna(vs.mean(axis=0))
vs1.head(10)
# Out:
#                 Vehicle_Type  Vehicle_Manoeuvre  \
# Accident_Index
# 200501BS00001            9.0               18.0
# 200501BS00002           11.0                4.0
# 200501BS00003           11.0               17.0
# 200501BS00003            9.0                2.0
# 200501BS00004            9.0               18.0
# 200501BS00005            3.0               18.0
# 200501BS00006            9.0                5.0
# 200501BS00006            3.0               18.0
# 200501BS00007            3.0               18.0
# 200501BS00007            9.0                2.0
#
#                 Vehicle_Location-Restricted_Lane  Skidding_and_Overturning  \
# Accident_Index
# 200501BS00001                                0.0                       0.0
# 200501BS00002                                0.0                       0.0
# 200501BS00003                                0.0                       0.0
# 200501BS00003                                0.0                       0.0
# ...

# %%
vs1.isnull().values.any()
# Out:
# False

# %%
#he reduce() function is used to apply a particular function passed in its argument to all of the list elements
from functools import reduce
dfs = [ac, casualities, vs1]
df_final = reduce(lambda left,right: pd.merge(left,right,on='Accident_Index'), dfs)#lambda takes in other functions as arguments
df_final.head()
# Out:
#                 Police_Force  Accident_Severity  Number_of_Vehicles  \
# Accident_Index
# 200501BS00001              1                  2                   1
# 200501BS00001              1                  2                   1
# 200501BS00002              1                  3                   1
# 200501BS00002              1                  3                   1
# 200501BS00003              1                  3                   2
#
#                 Number_of_Casualties                 Date  Day_of_Week  \
# Accident_Index
# 200501BS00001                      1 -9223372036854775808            3
# 200501BS00001                      1 -9223372036854775808            3
# 200501BS00002                      1 -9223372036854775808            4
# 200501BS00002                      1 -9223372036854775808            4
# 200501BS00003                      1 -9223372036854775808            5
#
#                                Time  Local_Authority_(District)  \
# Accident_Index
# ...

# %%
df_final.isnull().values.any()
# Out:
# False

# %% [markdown]
# # visualisations

# %%
# !pip install xgboost

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.model_selection import train_test_split
from sklearn.metrics import average_precision_score
from xgboost.sklearn import XGBClassifier
from xgboost import plot_importance
